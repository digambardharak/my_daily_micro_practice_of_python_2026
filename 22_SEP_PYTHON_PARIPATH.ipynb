# %% [markdown]
# <span style="color: red;">**if/else**</span>

# %% [markdown]
# **Q1. Write a Python program using if/else to check whether a given number is positive or negative.**

# %%
Number = int(input("Inter a Numbar: "))
if Number == Positive:
    print(f"{Number} is a Positive")
else:
    print(f"{Number} is Negative")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 Number = int(input("Inter a Numbar: "))
# ----> 2 if Number == Positive:
#       3     print(f"{Number} is a Positive")
#       4 else:
#
# NameError: name 'Positive' is not defined

# %%
num = int(input("Inter a number: "))
if num > 0:
    print(f"{num} is positive")
elif num < 0:
    print(f"{num} is negative")
else:
    print(f"{num} is zero")
# Out:
# -2 is negative

# %% [markdown]
# **Q2. Write a Python program using if/else to check whether a person is eligible to vote based on their age.**

# %%
age = int(input(" Inter your age: "))
if age >= 18:
    print(f" You are eligible for voting")
else:
    print(f"You are not eligible for voting")
# Out:
#  You are eligible for voting
