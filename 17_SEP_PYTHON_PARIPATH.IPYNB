# %% [markdown]
# <span style="color: red;">**Keywords**</span>

# %% [markdown]
# At the beginning of my Data Analyst journey, I knew <span style="color:red"><b>False</b></span> ideas could slow me down, and I had <span style="color:red"><b>None</b></span> of the skills I needed. Still, I believed my goal was <span style="color:red"><b>True</b></span>, so I learned Python <span style="color:red"><b>and</b></span> SQL <span style="color:red"><b>as</b></span> my first skills. I used <span style="color:red"><b>assert</b></span> to check my data, learned <span style="color:red"><b>async</b></span> work and <span style="color:red"><b>await</b></span> for tasks, and used <span style="color:red"><b>break</b></span> to stop a loop. I created a <span style="color:red"><b>class</b></span> to organize my code and used <span style="color:red"><b>continue</b></span> to skip bad data. With <span style="color:red"><b>def</b></span>, I created functions, and with <span style="color:red"><b>del</b></span>, I removed unwanted data. I used <span style="color:red"><b>elif</b></span> and <span style="color:red"><b>else</b></span> to make decisions, while <span style="color:red"><b>except</b></span> handled errors and <span style="color:red"><b>finally</b></span> finished my task safely. I used <span style="color:red"><b>for</b></span> to check each row and imported tools <span style="color:red"><b>from</b></span> Python libraries. I learned about <span style="color:red"><b>global</b></span> variables and used <span style="color:red"><b>if</b></span> to check clean data. I used <span style="color:red"><b>import</b></span> to bring libraries into my project, checked values <span style="color:red"><b>in</b></span> my dataset, and checked whether data <span style="color:red"><b>is</b></span> missing. I used <span style="color:red"><b>lambda</b></span> for a small transformation and learned about <span style="color:red"><b>nonlocal</b></span> variables. I used <span style="color:red"><b>not</b></span> and <span style="color:red"><b>or</b></span> for conditions, <span style="color:red"><b>pass</b></span> for an empty block, and <span style="color:red"><b>raise</b></span> for important errors. My function used <span style="color:red"><b>return</b></span> to give the result. I used <span style="color:red"><b>try</b></span> for risky code, <span style="color:red"><b>while</b></span> to repeat tasks, <span style="color:red"><b>with</b></span> to work safely with files, and <span style="color:red"><b>yield</b></span> to produce results one at a time. Step by step, I became more confident and moved closer to my Data Analyst dream.

# %% [markdown]
# <span style="color: red;">**Variables**</span>

# %% [markdown]
# **Q1. Create two variables a = 10 and b = 20, then print their values.*

# %%
a = 10
b = 20
print(a, b)
# Out:
# 10 20

# %% [markdown]
# **Q2. Swap the values of two variables a = 10 and b = 20 without using a third variable.*

# %%
a = 10
b = 20
a, b = b, a #swapin two variable without using temp
print(a, b)
# Out:
# 20 10

# %% [markdown]
# <span style="color: red;">**Data Types**</span>

# %% [markdown]
# **Q1. Create an integer and a float variable, then print their values and data types.*

# %%
Name = "Digambe"
Age = 25
Weight = 58.50

print(Name, type(Name))
print(Age, type(Age))
print(Weight, type(Weight))
# Out:
# Digambe <class 'str'>
# 25 <class 'int'>
# 58.5 <class 'float'>

# %% [markdown]
# **Q2. Create a string and a boolean variable, then print their values and data types.*

# %%
Name = "Digambaar"
Data_Analysis = True

print(Name, type(Name))
print(Data_Analysis, type(Data_Analysis))
# Out:
# Digambaar <class 'str'>
# True <class 'bool'>

# %% [markdown]
# <span style="color: red;">**Operators**</span>

# %% [markdown]
# **Q1. Create two numbers and use an arithmetic operator to calculate their sum.*

# %%
num1 = 10
num2 = 20
sum = num1 + num2 #addition of num1 and num2
print(sum)
# Out:
# 30

# %% [markdown]
# **Q2. Create two numbers and use a comparison operator to check whether the first number is greater than the second.*

# %%
num1 = 10
num2 = 20
if num1 > num2:
    print(num1, "is greater than", num2)
else:
    print(num2, "is a greater than", num1)

#Concept covered: Comparison operator > + if-else + variables.
# Out:
# 20 is a greater than 10
